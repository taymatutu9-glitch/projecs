# %%
arabic_dictionary = [

    "نعم", "لا", "مرحبا", "مع السلامة", "من فضلك", "شكرا", "آسف", "عفوا", "هيا", "تعال",
    "رجل", "امرأة", "طفل", "أب", "أم", "أخ", "أخت", "ابن", "بنت", "جد", "جدة", "صديق", "صديقة", "جار", "جيران",
    "منزل", "بيت", "غرفة", "مطبخ", "حمام", "سرير", "طاولة", "كرسي", "كنبة", "ثلاجة", "فرن", "مروحة", "سخان", "مكيف", "مصباح",
    "مدرسة", "صف", "طالب", "معلمة", "قلم", "دفتر", "كتاب", "سبورة", "ممحاة", "مسطرة", "حقيبة", "حاسوب", "حاسبة", "مكتبة", "محاضرة",
    "حب", "حزن", "فرح", "غضب", "خوف", "أمل", "سعادة", "ملل", "قلق", "راحة", "توتر", "طمأنينة", "دهشة", "فضول", "حيرة",
    "شجرة", "وردة", "زهرة", "نهر", "بحر", "جبل", "صحراء", "غابة", "عشب", "مطر", "ثلج", "رياح", "قمر", "شمس", "سماء",
    "قطة", "كلب", "جمل", "حصان", "بقرة", "غنم", "طائر", "سمكة", "نحلة", "فراشة", "ذئب", "أسد", "فيل", "نمر", "دجاجة",
    "مسجد", "كنيسة", "سوق", "مطعم", "مقهى", "مستشفى", "مكتبة", "حديقة", "ملعب", "مطار", "محطة", "مزرعة", "مصنع", "فندق", "متحف",
    "سيارة", "دراجة", "حافلة", "قطار", "طائرة", "سفينة", "شارع", "طريق", "إشارة", "كراج", "محرك", "مقود", "عجلة", "مقعد", "باب",
    "طبيب", "ممرضة", "معلم", "طالب", "محامي", "مهندس", "مزارع", "خباز", "جندي", "شرطي", "فنان", "كاتب", "رسام", "مصور", "مغني",
    "راقص", "ممثل", "مذيع", "سائق", "تاجر", "بائع", "نجار", "حداد", "عامل", "مدير", "رئيس", "سكرتير", "مدرب", "مدرس", "طيار",
    "ماء", "شاي", "قهوة", "عصير", "لبن", "حليب", "خبز", "رز", "لحم", "دجاج", "سمك", "تفاح", "موز", "تمر", "تمرية", "بيض", "جبن", "ملح", "سكر",
    "الآن", "غدًا", "أمس", "اليوم", "صباح", "مساء", "ليل", "نهار", "الجمعة", "السبت", "الأحد", "الاثنين", "الثلاثاء", "الأربعاء", "الخميس",
    "ساعة", "دقيقة", "ثانية", "أسبوع", "شهر", "سنة", "وقت", "لحظة", "متى", "قريبًا", "متأخر", "مبكر",
    "يكتب", "يقرأ", "يتكلم", "يشاهد", "يسمع", "ينام", "يستيقظ", "يأكل", "يشرب", "يركض", "يقفز", "يجلس", "يذهب", "يعود", "يسافر",
    "يحب", "يكره", "ينجح", "يفشل", "يتعلم", "يدرس", "يفكر", "يعرف", "يسأل", "يجيب", "يرسم", "يغني", "يضحك", "يبكي", "يلعب", "يعمل",
    "كبير", "صغير", "سريع", "بطيء", "قوي", "ضعيف", "طويل", "قصير", "ذكي", "غبي", "جميل", "قبيح", "ساخن", "بارد", "قريب", "بعيد",
    "جديد", "قديم", "مهم", "سهل", "صعب", "خطير", "آمن", "مشهور", "مجهول", "هادئ", "صاخب",
    "لغة", "كلمة", "جملة", "رقم", "صوت", "لون", "أحمر", "أخضر", "أزرق", "أسود", "أبيض", "أصفر", "بني", "رمادي", "برتقالي", "بنفسجي",
    "ثقافة", "دين", "تاريخ", "فن", "علم", "سياسة", "اقتصاد", "رياضة", "موسيقى", "رقص", "شعر", "قصة", "رواية", "تكنولوجيا", "إنترنت"
        "ال", "في", "من", "على", "أن", "إلى", "عن", "هو", "مع", "كان", "هذا", "ما", "لا", "كل", "قد", "أنا", "لكن", "إذا", "أو", "كما", 
    "نحن", "أنت", "هم", "هي", "هناك", "هنا", "ذلك", "هذه", "أولئك", "الذين", "التي", "الذي", "اللاتي", "اللواتي", "أين", "متى", "كيف", 
    "لماذا", "لأن", "أي", "بعض", "أكثر", "أقل", "جميع", "بين", "بعد", "قبل", "حتى", "ثم", "أيضًا", "أسبوع", "شهر", "سنة", "عمر", 
    "دقائق", "ثواني", "دقيقة", "شخص", "جميع", "مستقبل", "ماضي", "لحظة", "فكرة", "مشروع", "عمل", "دراسة", "كتاب", "جريدة", "مقال", 
    "موسيقى", "فيلم", "رياضة", "صحة", "علم", "تعليم", "مدينة", "قرية", "سوق", "شارع", "مستشفى", "مدرسة", "جامعة", "مكتبة", "مقهى", 
    "مطعم", "سيارة", "طائرة", "قطار", "حافلة", "دراجة", "سفر", "رحلة", "عطلة", "صيف", "شتاء", "ربيع", "خريف", "شجرة", "زهرة", "نبات", 
    "حيوان", "طائر", "سمك", "دجاج", "لحمة", "خضار", "فاكهة", "ماء", "شاي", "قهوة", "عصير", "حلويات", "حساء", "غذاء", "عشاء", "فطور", 
    "نوم", "استيقاظ", "وقت", "ساعة", "دقيقة", "ثانية", "مبكر", "متأخر", "صباح", "مساء", "ظهيرة", "ليل", "فرح", "حزن", "غضب", "حب", 
    "كراهية", "سلام", "ألم", "سعادة", "شقاء", "نجاح", "فشل", "مشكلة", "حل", "سؤال", "جواب", "موافقة", "رفض", "قوة", "ضعف", "مقاومة", 
    "حركة", "سكون", "مغامرة", "خطر", "أمان", "قلق", "طموح", "حلم", "واقع", "خيال", "إيمان", "شك", "وعد", "كذب", "صدق", "تفكير", "حكمة", 
    "معتقد", "ديانة", "دين", "ثقافة", "عقل", "روح", "جسد", "طبيعة", "كون", "سماء", "أرض", "بحر", "جبال", "صحراء", "وادي", "غابة", 
    "جزيرة", "خليج", "محيط", "نهر", "بحيرة", "قمة", "ساحل", "مزارع", "شواطئ", "تضاريس", "طبيعة", "جو", "مناخ", "غيم", "شمس", "قمر", 
    "نجوم", "كواكب", "سماء", "فضاء", "مجرة", "كوكب", "أرض", "حركة", "دوران", "جاذبية", "رياح", "عاصفة", "صاعقة", "رعد", "برق", 
    "غروب", "شروق", "صباح", "مساء", "هدوء", "ضوضاء", "سلام", "نزاع", "حرب", "سلام", "انتصار", "هزيمة", "مقاومة", "تسوية", "اتفاق", 
    "علاقة", "حياة", "موت", "أسرة", "عائلة", "أم", "أب", "ابن", "ابنة", "زوج", "زوجة", "أخ", "أخت", "جد", "جدة", "أبناء", "أحفاد", 
    "أصدقاء", "رفيق", "صديق", "عدو", "جار", "معارف", "معلومات", "اتصالات", "رسالة", "بريد", "هاتف", "مكالمات", "تقنيات", "إنترنت", 
    "شبكة", "موقع", "وسائل", "تواصل", "تطبيق", "برنامج", "حاسوب", "كمبيوتر", "جهاز", "شاشة", "لوحة", "كيبورد", "ماوس", "نظام", 
    "شبكة", "خوادم", "بيانات", "معلومات", "ذكاء", "اصطناعي", "محتوى", "صور", "فيديو", "موسيقى", "مقاطع", "دروس", "تدريب", "تعليم", 
    "تعليمات", "شهادة", "دبلوم", "درجة", "دورة", "مؤتمر", "ندوة", "ورشة", "زيارة", "اجتماع", "عرض", "فيلم", "برنامج", "محاضرة", 
    "مؤسسة", "شركة", "سوق", "مستثمر", "رأس", "مال", "أسهم", "بورصة", "اقتصاد", "تجارة", "منتجات", "صناعة", "تصنيع", "بيع", "شراء", 
    "تسويق", "عرض", "طلب", "شراء", "بيع", "تصدير", "استيراد", "مستورد", "تجارة", "مقاولة", "صفقة", "عمل", "وظيفة", "شاغر", "توظيف", 
    "مقاولة", "شركة", "مسؤولية", "مهام", "إدارة", "تنظيم", "تخطيط", "تسليم", "استلام", "مستودع", "مخزن", "مبيعات", "عملاء", "خدمة", 
    "زبون", "عميل", "سوق", "شركة", "منتج", "تصنيع", "تحليل", "استشارات", "مستشار", "دراسة", "تحليل", "تقرير", "مراجعة", "إصلاح", 
    "تحسين", "تطوير", "مبادرة", "ابتكار", "بحث", "أبحاث", "دراسة", "نتائج", "علم", "تكنولوجيا", "اختراع", "ابتكار", "مفهوم", "مقاربة", 
    "نظرية", "إستراتيجية", "مخطط", "دراسة", "خطة", "تخطيط", "تصميم", "مؤتمر", "ندوة", "ورشة", "مبادئ", "حسابات", "رياضيات", "علوم", 
    "كيمياء", "فيزياء", "هندسة", "أدوات", "تقنيات", "برمجة", "تطوير", "إلكترونيات", "روبوتات", "ذكاء", "اصطناعي", "ذكاء", "آلي", "خوارزميات", 
    "دوال", "خلايا", "معاملات", "بيانات", "تسلسل", "مصفوفات", "كود", "شفرة", "برنامج", "جافا", "بايثون", "سي", "فورتران", "الغة", "البرمجة", 
    "تحويل", "تخزين", "واجهة", "شبكات", "خادم", "عميل", "دورة", "مكتبة", "أداة", "أرشفة", "بحث", "ترتيب", "استعلام", "مسار", "خوارزمية", 
    "تحليل", "تصنيف", "تجميع", "اختبار", "تدريب", "تقييم", "نمذجة", "إدخال", "إخراج", "فهرسة", "خطة", "أداء", "استجابة", "ذاكرة", "مصفوفة", 
    "دالة", "تدفق", "مؤشر", "قيمة", "تكرار", "جداول", "خلايا", "بيانات", "صفوف", "أعمدة", "جدول", "نمط", "مصفوفة", "تمثيل", "كائن", 
    "كود", "استرجاع", "بحث", "حجز", "تحسين", "مصفوفات", "استدلال", "ترتيب", "مقارنة", "استخراج", "إضافة", "حذف", "تعديل", "تسلسل", "تخزين", 
    "استعمال", "تصفية", "نقل", "مزامنة", "نسخ", "ترجمة", "توصيف", "مسار", "فاصل", "توصيل", "ارتباط", "مترجم", "تنسيق", "ترقيم", "محاكاة", 
    "دمج", "فصل", "ضغط", "مستوى", "تقدير", "تمييز", "إصدار", "استجابة", "تحميل", "تحميل", "دورة", "نظام", "مفاتيح", "مصفوفات", "تعدد"
]

def edit_distance(str1, str2):
    m, n = len(str1), len(str2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(m + 1):
        dp[i][0] = i
    for j in range(n + 1):
        dp[0][j] = j

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if str1[i - 1] == str2[j - 1]:
                cost = 0
            else:
                cost = 2  

            dp[i][j] = min(
                dp[i - 1][j] + 1,    
                dp[i][j - 1] + 1,      
                dp[i - 1][j - 1] + cost  
            )

    return dp[m][n]


def suggest_corrections(input_word, dictionary, top_n=3):
    distances = [(word, edit_distance(input_word, word)) for word in dictionary]
    distances.sort(key=lambda x: x[1])
    return distances[:top_n]


user_input = input("أدخل الكلمة التي تريد تصحيحها: ")
suggestions = suggest_corrections(user_input, arabic_dictionary)

print("أقرب الكلمات:")
for word, dist in suggestions:
    print(f"- {word}")
